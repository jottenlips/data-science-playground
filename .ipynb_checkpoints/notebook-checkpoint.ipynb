# %%
import pandas as pd
json_normalize = pd.io.json.json_normalize
# Shift enter to run cell
json_data = pd.read_json("example.json")

# %%
# Normalize your data thats nested
json_normalize(json_data['cat-breeds'])
# Out:
#                  breed                                            country  \
# 0           Abyssinian                                           Ethiopia
# 1               Aegean                                             Greece
# 2        American Curl                                      United States
# 3     American Bobtail                                      United States
# 4   American Shorthair                                      United States
# 5    American Wirehair                                      United States
# 6          Arabian Mau                                  Arabian Peninsula
# 7      Australian Mist                                          Australia
# 8                Asian  developed in the United Kingdom (founding stoc...
# 9  Asian Semi-longhair                                     United Kingdom
#
#              origin        coat                    pattern
# 0  Natural/Standard       Short                     Ticked
# ...
